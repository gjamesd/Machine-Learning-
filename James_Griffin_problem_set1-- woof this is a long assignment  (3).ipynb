# %% [markdown]
# # James Griffin
# ## homework 1
# ### econ 487 machine learning

# %% [markdown]
# # Problem Set 1
# This problem set is largely based off of the application problems in the applied excercises in ISLR in chapters 2,3,10

# %%
# use this cell to import the modules you will be using
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt

# %% [markdown]
# ## Chapter 2
#
# ### 8
# This exercise relates to the College data set, which can be found in the file College.csv. It contains a number of variables for 777 different universities and colleges in the US. The variables are
# * Private : Public/private indicator
# * Apps : Number of applications received
# * Accept : Number of applicants accepted
# * Enroll : Number of new students enrolled
# * Top10perc : New students from top 10 % of high school class
# * Top25perc : New students from top 25 % of high school class
# * F.Undergrad : Number of full-time undergraduatesP.Undergrad : Number of part-time undergraduates
# * Outstate : Out-of-state tuition
# * Room.Board : Room and board costs
# * Books : Estimated book costs
# * Personal : Estimated personal spending
# * PhD : Percent of faculty with Ph.D.’s
# * Terminal : Percent of faculty with terminal degree
# * S.F.Ratio : Student/faculty ratio
# * perc.alumni : Percent of alumni who donate
# * Expend : Instructional expenditure per student
# * Grad.Rate : Graduation rate
# Before reading the data into python, it can be viewed in Excel or a text editor is well.

# %% [markdown]
# ### (a)
# Use the pandas read_csv() function to read the data into python. Call the loaded data df. Make sure that you have the directory set to the correct location for the data or use the absolute filepath so the program knows where to look for the file. Use df.head() to show the first 10 observations of the data

# %%
df = pd.read_csv("College.csv")
#df.head()

# %% [markdown]
# ### (b)
# Read in the data again this time calling the data college and using the parameter index_col=0 in the read_csv function. Notice the difference between the index attributes

# %%
df2 = pd.read_csv("College.csv", index_col = 0)
df2.head()

'''the difference is that the indexcies are done alphabetically by name instead of by row like above'''
# Out:
# 'the difference is that the indexcies are done alphabetically by name instead of by row like above'

# %% [markdown]
# ### (c)
# Now we will do some prelimainary analysis and visualizations of the data that was loaded
# $\mathbf{i)}$ Use the describe method of the dataframe object that you made by reading in the data to show the summary statistics of each of the columns

# %%
df2.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# min      139.000000      1.000000   2340.000000  1780.000000    96.000000
# 25%      992.000000     95.000000   7320.000000  3597.000000   470.000000
# 50%     1707.000000    353.000000   9990.000000  4200.000000   500.000000
# 75%     4005.000000    967.000000  12925.000000  5050.000000   600.000000
# max    31643.000000  21836.000000  21700.000000  8124.000000  2340.000000
#
#           Personal         PhD    Terminal   S.F.Ratio  perc.alumni  \
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean   1340.642214   72.660232   79.702703   14.089704    22.743887
# std     677.071454   16.328155   14.722359    3.958349    12.391801
# min     250.000000    8.000000   24.000000    2.500000     0.000000
# 25%     850.000000   62.000000   71.000000   11.500000    13.000000
# 50%    1200.000000   75.000000   82.000000   13.600000    21.000000
# 75%    1700.000000   85.000000   92.000000   16.500000    31.000000
# max    6800.000000  103.000000  100.000000   39.800000    64.000000
#
#              Expend  Grad.Rate
# count    777.000000  777.00000
# mean    9660.171171   65.46332
# std     5221.768440   17.17771
# min     3186.000000   10.00000
# 25%     6751.000000   53.00000
# 50%     8377.000000   65.00000
# 75%    10830.000000   78.00000
# max    56233.000000  118.00000

# %%
df2.columns
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#        'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#        'Grad.Rate'],
#       dtype='object')

# %% [markdown]
# $\mathbf{ii)}$ Use the scatter_matrix function that was imported from pandas to produce scatter plots of the pairwise combinations of 6 of the variables of your choice. Try adjusting the figsize parameter make the displayed fill the area of the display under the cell while keeping it looking nice

# %%
# call the function above these lines, these will make it cleaner and display the image
df3 = df2[["Books", "P.Undergrad", "Outstate",
                  "Room.Board", "Accept", "Enroll"]]
scatter_matrix(df3, alpha = .2)
scatter_matrix
plt.tight_layout()
plt.show()

# %% [markdown]
# $\mathbf{iii)}$ Use seaborn's boxplot function to create a boxplot of Outstate on private.
# Hint: You can either pass in the columns as objects or the names of the columns and use data=college as a parameter

# %%
import seaborn as sns 

iii = sns.boxplot(x = "Outstate", y = "Private", data = df2)

# %% [markdown]
# $\mathbf{iv)}$  Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %.

# %%
df2.head()
df2.Top10perc

t10 = []
for i in range(len(df2.Top10perc)):
    if df2.Top10perc[i] >=50:
        t10.append(1)
    else:
        t10.append(0)

df2["top_10_indicator"] = t10
#df2.head()

# %% [markdown]
# Get a count of how many universities are in the 'Elite' category. Now make boxplot of Outstate versus Elite.

# %%
print(sum(df2.top_10_indicator))

ten = sns.boxplot(x = df2.top_10_indicator, y = df2.Outstate)
# Out:
# 83

# %% [markdown]
# $\mathbf{v)}$ Use seaborn's distplot function to produce some histograms with differing numbers of bins for a few of the quantitative variables.

# %%
sns.distplot(df2["PhD"])
# Out:
# C:\Users\13855\Anaconda_Re_do\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df2["Grad.Rate"])

# %%
sns.distplot(df2["Room.Board"])

# %% [markdown]
# You can create a grid of histograms with the hist method of the dataframe

# %% [markdown]
# Using the tools that were introduced and/or other ones you find, continue exploring the data set and write a brief summary of what you find. This should involve something you do that was not a part of the previous responses.

# %%
#look for null data
df2.isnull().sum()
# Out:
# Private             0
# Apps                0
# Accept              0
# Enroll              0
# Top10perc           0
# Top25perc           0
# F.Undergrad         0
# P.Undergrad         0
# Outstate            0
# Room.Board          0
# Books               0
# Personal            0
# PhD                 0
# Terminal            0
# S.F.Ratio           0
# perc.alumni         0
# Expend              0
# Grad.Rate           0
# top_10_indicator    0
# dtype: int64

# %%
'''
Wanted to make sure that we did not have null data. 
if we do, we have to find a way to deal with that 
because machine learning models struggle with nulls
- depending on the amount of null data, we can simply
delete the null observations, fill with the mean, or
find some other way to insert a value.

'''
# Out:
# '\nWanted to make sure that we did not have null data. \nif we do, we have to find a way to deal with that \nbecause machine learning models struggle with nulls\n- depending on the amount of null data, we can simply\ndelete the null observations, fill with the mean, or\nfind some other way to insert a value.\n\n'

# %% [markdown]
# ## Chapter 3
# $\mathbf{a)}$Load in auto.csv as a dataframe and the produce a grid of the pairwise scatterplots of the variables of the dataframe

# %%
auto = pd.read_csv("Auto.csv")
#auto.head()

# %% [markdown]
# $\mathbf{b)}$ Show the correlation matrix. There are several ways to do this but you should be able to find a function that makes it for the numeric variables of a dataframe.

# %%
import numpy as np

#selecting only the numeric features -- i ignored horsepower due to missing values 
numeric_features = auto.select_dtypes(include=[np.number])
#creating a correlation object 
corr = numeric_features.corr()
#creating heat map
sns.heatmap(corr,vmax=.8,square=True, annot = True)

# %% [markdown]
# $\mathbf{c)}$ Use the statsmodel OLS function to perform a linear regression with mpg as the response and year as a feature. Use the summary() method to print the results.

# %%
numeric_features.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'year',
#        'origin'],
#       dtype='object')

# %%
# fill in the variable names you plan on using in the regression
X = auto.loc[:,['cylinders','displacement',
               "weight", "acceleration", "year", "orgin"]]
print(X.shape)

X.isnull().sum()
# Out:
# (397, 6)
# C:\Users\13855\Anaconda_Re_do\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# cylinders         0
# displacement      0
# weight            0
# acceleration      0
# year              0
# orgin           397
# dtype: int64

# %%
X = auto.loc[:,['cylinders','displacement',
               "weight", "acceleration", "year"]]

y = auto['mpg']
print(y.shape)
type(y)
reg_obj = sm.OLS(y.astype(float) ,X.astype(float))

results = reg_obj.fit()
print(results.summary())
# Out:
# (397,)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     3929.
# Date:                Sun, 22 Sep 2019   Prob (F-statistic):               0.00
# Time:                        01:52:49   Log-Likelihood:                -1056.8
# No. Observations:                 397   AIC:                             2124.
# Df Residuals:                     392   BIC:                             2144.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# cylinders       -0.4964      0.330     -1.505      0.133      -1.145       0.152
# displacement     0.0077      0.007      1.060      0.290      -0.007       0.022
# weight          -0.0069      0.001    -11.476      0.000      -0.008      -0.006
# acceleration     0.0298      0.078      0.382      0.703      -0.123       0.183
# year             0.5911      0.021     28.746      0.000       0.551       0.631
# ==============================================================================
# Omnibus:                       51.361   Durbin-Watson:                   1.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.476
# Skew:                           0.757   Prob(JB):                     8.30e-21
# Kurtosis:                       4.816   Cond. No.                     5.84e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.84e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Do a linear regression with mpg as the outcome and all other variables except name as the predictors. Comment on the output. For instance:
# i. Is there a relationship between the predictors and the response?
# ii. Which predictors appear to have a statistically significant relationship to the response?
# iii. What does the coefficient for the year variable suggest?

# %%
### 1
''' So I dropped orgin from the regression because orgin had 397 out of 397 missing values, so I 
just ignored that column in my regression, the columns that were statistically significant were year and weight, the
other columns to not appear to be particularly predictive, however the Rsquared value is .98 so very good'''

### 2
'''see question 1, weight and year '''

### 3
'''that for every year newer that the car becomes the car gets .5911 more miles per gallon'''
# Out:
# 'that for every year newer that the car becomes the car gets .5911 more miles per gallon'

# %% [markdown]
# $\mathbf{d)}$ Use statsmodels' inluence_plot() function to produce diagnostic plots of the linear regression fit. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?

# %%
#creating figure 
fig, ax = plt.subplots(figsize=(12,8))
#creating plot 
fig = sm.graphics.influence_plot(results, ax=ax, criterion="cooks")

# %% [markdown]
# $\mathbf{e)}$ Create some polynomial and interaction features from the existing set of variables and fit linear regression models with them. Do any interaction terms appear to be statistically significant? What about polynomial terms?
# You may want to look into sklearn's PatsyTransformer if you are going to create a lot but this  is not necessary

# %%
auto.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
#from the skitlearn preprocessing get a polynomial featues
#which makes creating interaction terms suuuuper easy
from sklearn.preprocessing import PolynomialFeatures
#creating interaction of degree two, ignoring bias, and only doing the interaction
poly_reg = PolynomialFeatures(degree = 2, interaction_only=True, include_bias = False)

from sklearn.linear_model import LinearRegression
#creating an object from that class
lin_reg = LinearRegression()

#creating a regression with polynomial terms
X_poly = poly_reg.fit_transform(X)
polyreg = sm.OLS(y, X_poly).fit()

#X_poly.shape
#y.shape
print(polyreg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                     2021.
# Date:                Sun, 22 Sep 2019   Prob (F-statistic):               0.00
# Time:                        01:52:50   Log-Likelihood:                -967.03
# No. Observations:                 397   AIC:                             1964.
# Df Residuals:                     382   BIC:                             2024.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            11.4595      6.390      1.793      0.074      -1.105      24.024
# x2            -0.2967      0.133     -2.224      0.027      -0.559      -0.034
# x3             0.0098      0.012      0.822      0.412      -0.014       0.033
# x4            -5.9472      1.144     -5.197      0.000      -8.197      -3.697
# x5             0.8259      0.107      7.738      0.000       0.616       1.036
# x6            -0.0076      0.003     -2.190      0.029      -0.014      -0.001
# x7             0.0004      0.001      0.801      0.424      -0.001       0.001
# x8             0.1447      0.109      1.330      0.184      -0.069       0.359
# x9            -0.1703      0.082     -2.077      0.039      -0.332      -0.009
# x10         2.244e-05   6.91e-06      3.248      0.001    8.86e-06     3.6e-05
# x11           -0.0059      0.002     -2.515      0.012      -0.011      -0.001
# x12            0.0046      0.002      2.457      0.014       0.001       0.008
# x13            0.0003      0.000      1.813      0.071   -2.87e-05       0.001
# x14           -0.0004      0.000     -2.430      0.016      -0.001   -7.26e-05
# x15            0.0715      0.014      5.088      0.000       0.044       0.099
# ==============================================================================
# Omnibus:                       43.438   Durbin-Watson:                   1.470
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.908
# Skew:                           0.590   Prob(JB):                     4.06e-21
# Kurtosis:                       5.070   Cond. No.                     3.93e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.93e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# #from the skitlearn preprocessing get a polynomial featues
# #which makes creating interaction terms suuuuper easy
# from sklearn.preprocessing import PolynomialFeatures
# #creating interaction of degree two, ignoring bias, and only doing the interaction
# poly_reg = PolynomialFeatures(degree = 2, interaction_only=True, include_bias = False)

# #creating an object from the linear regression class
# lin_reg = LinearRegression()

# #making sure I am only using numeric variables for interactions
# print(X.columns)
# #print(X.acceleration[2])
# #creating a regression with polynomial terms
# #X_poly = poly_reg.fit_transform(X)
# lin_reg.fit(X, y)
# polyreg = sm.OLS(y.astype(float), X_poly.astype(float))
# poly_res = polyreg.fit(X_poly)

# #X_poly.shape
# #y.shape
# print(poly_res.summary())

# %% [markdown]
# # Chapter 10
# ## PCA
# In the first cell I have some code which will generate some random data with 500 features and 10000 observations. There will be 3 clusters of groups indicated by the y variable. Use PCA to reduce the dimensionality down to 2 principle components. Sklearn has a PCA and TruncatedSVD object you can use, the difference will just be demaning the values or not so there shouldn't be a big difference in results.

# %%
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA

SEED = 123
X, y = make_blobs(n_samples=1000, n_features=5000, cluster_std=90., random_state=SEED)
print("Original shape: {}".format(str(X.shape)))
# Out:
# Original shape: (1000, 5000)

# %%
#creating a standard scaler object
from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# #scaling the data --> every option will be between 0,1
x = StandardScaler().fit_transform(X)
#scaler.fit(X)
# X_scaled = scaler.transform(X_scaled)

pca = PCA(n_components=2)
#creating principal components 
principalComponents = pca.fit_transform(X)

principalDf = pd.DataFrame(data = principalComponents,
                          columns = ["1 pca", "2 pca"])

# transform data onto the first two principal components
principalDf["y"] = y

# %% [markdown]
# Generate a plot of the 2 principal components that were found. You may find it helpful to combine X and y into a pandas DataFrame object so that it plays mroe nicely with seaborn.

# %%
pcdf = pd.DataFrame(principalDf, y, columns = ["1", "2"])
pcdf.columns

sns.scatterplot(x = principalDf["1 pca"], y = principalDf["2 pca"], data = principalDf)
plt.xlabel("x label")
plt.ylabel("y label")
plt.xlabel("1 pca")
plt.ylabel('2pca')
#plt.legend()
plt.show()

# %% [markdown]
# ## KMeans
# In order to prevent overfitting, we can split the data into to groups of data for training and some for the validating of our model, often called test. An easy way to divide this is to use sklearn's traintestsplit function. Use the larger portion fo your data for training and the smaller set for the validation.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
# split the data in training and test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)

# %% [markdown]
# Perform K-means clustering of the observations with K = 3. How well do the clusters that you obtained in K-means clustering compare to the true class labels? You can use the classifcation report function from skelarn to get some metrics that measure the quality of the model you used.

# %%
pca = PCA(n_components=3)

'''OK so we took out one more dimention of 
our training data '''

#fitting our training data on our pca only having 2 
pca.fit(X_train)
#transforming into two components 
X_pca = pca.transform(X_train)
print("Original shape: {}".format(str(X_train.shape)))
print("PCA Shape: {}".format(str(X_pca.shape)))
# Out:
# Original shape: (750, 5000)
# PCA Shape: (750, 3)

# %%
df1 = pd.DataFrame(X_pca)
df1 = df1.rename(columns = {"0":"zero"})
#making sure I only have numeric data 
numeric_features = df1.select_dtypes(include=[np.number])

#kmeans with three clusters 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

kmeans = KMeans(n_clusters=3, n_init=50, n_jobs=-1)
kmeans.fit(df1)
sk_clusters = kmeans.predict(df1)

labels = kmeans.labels_
print(silhouette_score(df1, labels, metric='euclidean'))
#plt.scatter(df[0], df1[1],df[2], c=sk_clusters)
'''
the sillouette score ranges from -1 to 1 and is
used to determine the similarity within clusters,
so a score of .36 means that there is a reasonable
amount of similarity amoungst clusters when there are 
3 clustess 
'''
# Out:
# 0.3668320090066543
# '\nthe sillouette score ranges from -1 to 1 and is\nused to determine the similarity within clusters,\nso a score of .58 means that there is a reasonable\namount of similarity amoungst clusters when there are \n3 clustess \n'

# %% [markdown]
# Perform K-means clustering with K = 2. Describe your results.

# %%
#splitting again because I over rode the data above
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)
'''keeping the random state the same means i will have
the same sample in both the above and this cell
'''
pca = PCA(n_components=2)

'''OK so we took out one more dimention of 
our training data '''

#fitting our training data on our pca only having 2 
pca.fit(X_train)
#transforming into two components 
X_pca = pca.transform(X_train)
print("Original shape: {}".format(str(X_train.shape)))
print("PCA Shape: {}".format(str(X_pca.shape)))


df1 = pd.DataFrame(X_pca)
df1 = df1.rename(columns = {"0":"zero"})
#making sure I only have numeric data 
numeric_features = df1.select_dtypes(include=[np.number])

#kmeans with three clusters 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

kmeans = KMeans(n_clusters=3, n_init=50, n_jobs=-1)
kmeans.fit(df1)
sk_clusters = kmeans.predict(df1)

labels = kmeans.labels_
print(silhouette_score(df1, labels, metric='euclidean'))
#plt.scatter(df[0], df1[1],df[2], c=sk_clusters)
'''
for interpretation on silhouette score please see
above, it looks like with 2 pca's this is lots
better

'''
# Out:
# Original shape: (750, 5000)
# PCA Shape: (750, 2)
# 0.5224055525212568
# "\nfor interpretation on silhouette score please see\nabove, it looks like with 2 pca's this is slightly\nbetter but you have to go to the 6th or 7th decimal\nso they are essentially the same \n\n"

# %% [markdown]
# Now perform K-means clustering with K = 4, and describe your results.

# %%
# showing a different way to score and classify my results because I'm not 
#entierly sure what the problem wants so I am doing this way also 
#splitting again because I over rode the data above
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
pca.fit(X_train)
#transform data onto the first 4 principal components
X_pca = pca.transform(X)
print("Reduced shape: {}".format(str(X_pca.shape)))

knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
print("Test set score of 1-nn: {:.2f}".format(knn.score(X_test, y_test)))


"""classifying the data very poorly, the
#closer to 1 the better the data is being classified..
# so not great,"""
# Out:
# Reduced shape: (1000, 4)
# Test set score of 1-nn: 0.52
# 'classifying the data very poorly, the\n#closer to 1 the better the data is being classified..\n# so not great,'

# %% [markdown]
# Now perform K-means clustering with K = 3 on the first two principal component score vectors, rather than on the raw data. That is, perform K-means clustering on the 60 × 2 matrix of which the first column is the first principal component score vector, and the second column is the second principal component score vector. Comment on the results.

# %%
df1.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
'''I really dont want to lol'''

## so heeeere we go 
## ok so k means on the clustered data, 
## imma just use X_train cuz its already in a data
#frame and 

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, n_init=50, n_jobs=-1)
kmeans.fit(df1)
sk_clusters = kmeans.predict(df1)

plt.scatter(df1[0], df1[1], c=sk_clusters)
plt.xlabel("1st")
plt.ylabel("2nd")
# Out:
# Text(0, 0.5, '2nd')

# %% [markdown]
# Well, this looks oddly similar to the graph above, I'm not 100 percent sure what data I'm suppose to use for this, I think that might be the issue, but I think this is the right one.. either way, thats the idea of how to graph K means clustering

# %% [markdown]
# Using of of sklearn's data scalers, perform K-means clustering with K = 3 on the data after scaling each variable to have standard deviation one. How do these results compare to those obtained in (b)? Explain.

# %%
'''standard scaling smooshes varience in 
observations because it forces everything to be 
between -1 and 1.  Particularly good when there 
is lots of varience or you are trying to improve 
a machine learning model and do not want certain 
parameters to be out weighing others.  This also
is potentially good for activation functions'''


# creating a standard scaler 
from sklearn.preprocessing import StandardScaler
#creating an object from the SS class 
sc = StandardScaler()
#smooshing my data 
scd = sc.fit_transform(df1)
scd = pd.DataFrame(scd)

kmeans = KMeans(n_clusters=2, n_init=50, n_jobs=-1)
kmeans.fit(scd)
sk_clusters = kmeans.predict(scd)
print(scd.shape)
plt.scatter(scd[0], scd[1], c=sk_clusters)
plt.xlabel("1st")
plt.ylabel("2nd")
plt.show()
# Out:
# (750, 2)

# %% [markdown]
# The picture looks to be the same except the clusters have switched sides and sizes.  the colpsing of the data almost inverted the data it appears..

# %% [markdown]
# ### book problems I didn't want to do by hand

# %%
matrix = [[26, -19], [-19, 14]]

np.linalg.eig(matrix)
# Out:
# (array([39.92485885,  0.07514115]), array([[ 0.80657652,  0.59112969],
#         [-0.59112969,  0.80657652]]))

# %%
#question 8 10.2 all of this -- see book work 

prob8 = [[0, .3,.4,.7],
        [.3, 0, .5, .8],
        [.4, .5, 0, .45],
        [.7, .8, .45, 0]]
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(prob8, 'complete')
_ = dendrogram(Z)

Y = linkage(prob8, 'single')
_ = dendrogram(Y)
# Out:
# C:\Users\13855\Anaconda_Re_do\lib\site-packages\ipykernel_launcher.py:6: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#
# C:\Users\13855\Anaconda_Re_do\lib\site-packages\ipykernel_launcher.py:9: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   if __name__ == '__main__':

# %%
#question 8 10.3

one = [1,1,0,5,6,4]
two = [4,3,4,1,2,0]

mat = pd.DataFrame(one)
mat['two'] = two

plt.scatter(one, two)

# %%
#chose a random sample
from random import sample
mat.sample(frac = .5, replace = False)
# Out:
#    0  two
# 4  6    2
# 2  0    4
# 1  1    3

# %%
c1x = np.mean([6,0])
c1y = np.mean([0,1])
c1 = (c1x, c1y)
c2x = np.mean([2,4])
c2y = np.mean([4,3])
c2 = (c2x, c2y)

# %%
plt.scatter(one, two)
plt.scatter(c1, c2)

# %%
from sklearn.metrics.pairwise import euclidean_distances

def k_means(k, data):
    copy_data = data.copy()
    rows, features = copy_data.shape
    copy_data['cluster_assignments'] = np.random.randint(0, k, rows)
    did_change = 1
    while did_change:
        centroids = copy_data.groupby('cluster_assignments').mean()
        new_assignments = np.argmin(euclidean_distances(data.values[:,:features], centroids.values), 1)
        if np.array_equal(copy_data['cluster_assignments'].values, np.array(new_assignments)):
            did_change = 0
        else:
            copy_data['cluster_assignments'] = new_assignments
    return copy_data['cluster_assignments'].values

# %%
clusters = k_means(2, mat)

plt.scatter(mat[0], mat["two"], c = clusters)
